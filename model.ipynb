# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/Machine Learning/Insurance Price/insurance.csv')
df
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    1  27.900         0       1  16884.92400
# 1      18    0  33.770         1       0   1725.55230
# 2      28    0  33.000         3       0   4449.46200
# 3      33    0  22.705         0       0  21984.47061
# 4      32    0  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    0  30.970         3       0  10600.54830
# 1334   18    1  31.920         0       0   2205.98080
# 1335   18    1  36.850         0       0   1629.83350
# 1336   21    1  25.800         0       0   2007.94500
# 1337   61    1  29.070         0       1  29141.36030
#
# [1338 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates()
print(df.duplicated().sum())
df
# Out:
# 0
#       age  sex     bmi  children  smoker      charges
# 0      19    1  27.900         0       1  16884.92400
# 1      18    0  33.770         1       0   1725.55230
# 2      28    0  33.000         3       0   4449.46200
# 3      33    0  22.705         0       0  21984.47061
# 4      32    0  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    0  30.970         3       0  10600.54830
# 1334   18    1  31.920         0       0   2205.98080
# 1335   18    1  36.850         0       0   1629.83350
# 1336   21    1  25.800         0       0   2007.94500
# 1337   61    1  29.070         0       1  29141.36030
#
# [1337 rows x 6 columns]

# %%
df['bmi'] = np.round(df['bmi'], decimals = 2)

df
# Out:
# /var/folders/w6/5y382jhs5rz0cj000088z4_w0000gn/T/ipykernel_56570/3275360043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bmi'] = np.round(df['bmi'], decimals = 2)
#       age  sex    bmi  children  smoker      charges
# 0      19    1  27.90         0       1  16884.92400
# 1      18    0  33.77         1       0   1725.55230
# 2      28    0  33.00         3       0   4449.46200
# 3      33    0  22.70         0       0  21984.47061
# 4      32    0  28.88         0       0   3866.85520
# ...   ...  ...    ...       ...     ...          ...
# 1333   50    0  30.97         3       0  10600.54830
# 1334   18    1  31.92         0       0   2205.98080
# 1335   18    1  36.85         0       0   1629.83350
# 1336   21    1  25.80         0       0   2007.94500
# 1337   61    1  29.07         0       1  29141.36030
#
# [1337 rows x 6 columns]

# %%
df['charges'] = np.round(df['charges'], decimals = 2)
df
# Out:
# /var/folders/w6/5y382jhs5rz0cj000088z4_w0000gn/T/ipykernel_56570/1467477402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['charges'] = np.round(df['charges'], decimals = 2)
#       age  sex    bmi  children  smoker   charges
# 0      19    1  27.90         0       1  16884.92
# 1      18    0  33.77         1       0   1725.55
# 2      28    0  33.00         3       0   4449.46
# 3      33    0  22.70         0       0  21984.47
# 4      32    0  28.88         0       0   3866.86
# ...   ...  ...    ...       ...     ...       ...
# 1333   50    0  30.97         3       0  10600.55
# 1334   18    1  31.92         0       0   2205.98
# 1335   18    1  36.85         0       0   1629.83
# 1336   21    1  25.80         0       0   2007.94
# 1337   61    1  29.07         0       1  29141.36
#
# [1337 rows x 6 columns]

# %%
df['bmi'].unique()
# Out:
# array([27.9 , 33.77, 33.  , 22.7 , 28.88, 25.74, 33.44, 27.74, 29.83,
#        25.84, 26.22, 26.29, 34.4 , 39.82, 42.13, 24.6 , 30.78, 23.84,
#        40.3 , 35.3 , 36.01, 32.4 , 34.1 , 31.92, 28.02, 27.72, 23.08,
#        32.78, 17.39, 36.3 , 35.6 , 26.32, 28.6 , 28.31, 36.4 , 20.42,
#        32.97, 20.8 , 36.67, 39.9 , 26.6 , 36.63, 21.78, 30.8 , 37.05,
#        37.3 , 38.66, 34.77, 24.53, 35.2 , 35.62, 33.63, 28.  , 34.43,
#        28.69, 36.96, 31.82, 31.68, 22.88, 37.34, 27.36, 33.66, 24.7 ,
#        25.94, 22.42, 28.9 , 39.1 , 36.19, 23.98, 24.75, 28.5 , 28.1 ,
#        32.01, 27.4 , 34.01, 29.59, 35.53, 39.8 , 26.88, 38.28, 37.62,
#        41.23, 34.8 , 22.9 , 31.16, 27.2 , 26.98, 39.49, 24.8 , 31.3 ,
#        19.95, 19.3 , 31.6 , 25.46, 30.12, 29.92, 27.5 , 28.4 , 30.88,
#        27.94, 35.09, 29.7 , 35.72, 32.2 , 49.06, 27.17, 23.37, 37.1 ,
#        23.75, 28.98, 31.35, 33.92, 28.78, 28.3 , 37.4 , 17.76, 34.7 ,
#        26.5 , 22.04, 35.9 , 25.56, 28.05, 25.18, 31.9 , 36.  , 32.49,
#        25.3 , 29.74, 38.83, 30.5 , 37.73, 37.43, 24.13, 37.15, 39.52,
#        24.42, 27.83, 36.85, 39.6 , 29.8 , 29.64, 28.22, 37.  , 33.16,
#        18.9 , 41.47, 30.3 , 15.96, 33.34, 37.7 , 27.84, 29.2 , 26.41,
#        30.69, 41.9 , 30.9 , 32.11, 31.57, 26.2 , 30.59, 32.8 , 18.05,
#        39.33, 32.23, 24.04, 36.08, 22.3 , 26.4 , 31.8 , 26.73, 23.1 ,
#        23.21, 33.7 , 33.25, 24.64, 33.88, 38.06, 41.91, 31.64, 36.2 ,
#        17.8 , 24.51, 22.22, 38.39, 29.07, 22.14, 26.8 , 30.02, 35.86,
#        20.9 , 17.29, 34.21, 25.36, 40.15, 25.2 , 26.84, 24.32, 42.35,
#        19.8 , 30.2 , 29.37, 34.2 , 27.46, 27.55, 20.62, 24.3 , 31.79,
#        21.56, 28.12, 40.56, 27.64, 31.2 , 26.62, 48.07, 36.76, 33.4 ,
#        45.54, 28.82, 22.99, 27.7 , 25.41, 34.39, 22.61, 37.51, 38.  ,
#        33.33, 34.86, 33.06, 35.97, 31.4 , 25.27, 40.94, 36.48, 33.8 ,
#        36.7 , 36.38, 34.5 , 32.3 , 27.6 , 29.26, 35.75, 23.18, 25.6 ,
#        21.94, 24.97, 23.94, 34.48, 21.8 , 23.3 , 21.28, 29.4 , 27.3 ,
#        37.72, 23.76, 25.52, 27.61, 27.06, 39.4 , 34.9 , 22.  , 30.36,
#        27.8 , 53.13, 39.71, 32.87, 44.7 , 30.97])

# %%
df['smoker'].unique()
# Out:
# array([1, 0])

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
plt.scatter(df['children'],df['charges'])

# %%
ax = plt.axes(projection ='3d')
 
# defining all 3 axis
z = df['children']
x = df['charges']
y = df['smoker']
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot of Data')
plt.show()

# %%
plt.scatter(df['bmi'],df['charges'])

# %%
x = df.drop(columns='charges', axis=1)
y = df['charges']

x
# Out:
#       age  sex    bmi  children  smoker
# 0      19    1  27.90         0       1
# 1      18    0  33.77         1       0
# 2      28    0  33.00         3       0
# 3      33    0  22.70         0       0
# 4      32    0  28.88         0       0
# ...   ...  ...    ...       ...     ...
# 1333   50    0  30.97         3       0
# 1334   18    1  31.92         0       0
# 1335   18    1  36.85         0       0
# 1336   21    1  25.80         0       0
# 1337   61    1  29.07         0       1
#
# [1337 rows x 5 columns]

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.94
# 1337    29141.36
# Name: charges, Length: 1337, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       age  sex    bmi  children  smoker
# 660    37    0  46.53         3       0
# 505    37    0  30.88         3       0
# 1049   49    0  30.90         0       1
# 1099   25    1  33.99         1       0
# 201    48    1  32.23         1       0
# ...   ...  ...    ...       ...     ...
# 466    60    1  28.70         1       0
# 299    48    1  28.88         1       0
# 493    61    0  43.40         0       0
# 527    51    1  25.80         1       0
# 1193   48    1  36.58         0       0
#
# [1069 rows x 5 columns]

# %%
x_test
# Out:
#       age  sex    bmi  children  smoker
# 17     23    0  23.84         0       0
# 1091   55    1  29.83         0       0
# 273    50    0  27.46         1       0
# 270    18    0  29.37         1       0
# 874    44    0  21.85         3       0
# ...   ...  ...    ...       ...     ...
# 232    19    1  17.80         0       0
# 323    57    0  40.94         0       0
# 1192   58    1  32.40         1       0
# 1066   48    0  37.29         2       0
# 960    19    1  39.62         1       0
#
# [268 rows x 5 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.7136372845739056

# %%
plt.scatter(y_test,y_pred)

# %%
import seaborn as sns
sns.regplot(x=y_test,y=y_pred,ci=None,color ='red')
# Out:
# <Axes: xlabel='charges'>

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(lr, open(filename, 'wb'))
